# %%
import numpy as np

# %%
### sigmoid 函数
def sigmoid(x):
    """
    输入：x：数组
    输出：z：经过sigmoid函数计算之后的数组
    """
    z = 1 / (1 + np.exp(-x))
    return z

# %%
### 定义参数初始化函数
def initialize_params(dims):
    W = np.zeros((dims, 1))
    b = 0
    return W, b
